# %% [markdown]
# # Orchestration
# This notebook will run the gold layer transformations notebooks in sequence

# %%
notebooks = [
    "./gold_dim_customers",
    "./gold_dim_products",
    "./gold_fact_sales"
]

for nb in notebooks:
    dbutils.notebook.run(nb, timeout_seconds=0)
    print(f" {nb} was run successfully")
